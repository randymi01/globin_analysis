# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# %%
pbmc = pd.read_csv("pbmc_polya.csv")
skin = pd.read_csv("skin_polya.csv")

# %%
pbmc_u = pbmc.pivot(index='Sample', columns='Stat', values='Value')[["Assigned","Unassigned_Ambiguity","Unassigned_MultiMapping","Unassigned_NoFeatures", "Unassigned_Unmapped"]]

# %%
pbmc_u = pbmc_u.apply(pd.to_numeric, errors='coerce').astype(int)

# %%
skin_u = skin.pivot(index='Sample', columns='Stat', values='Value')[["Assigned","Unassigned_Ambiguity","Unassigned_MultiMapping","Unassigned_NoFeatures", "Unassigned_Unmapped"]]
skin_u = skin_u.apply(pd.to_numeric, errors='coerce').astype(int)

# %%
skin_u
# Out:
# Stat               Assigned  Unassigned_Ambiguity  Unassigned_MultiMapping  \
# Sample
# HS_299_PolyA_skin  14255241               1740751                 19068863
# HS_644_PolyA_skin  13612285               1662317                 24148741
# HS_672_PolyA_skin  14857851               1937898                 22922755
# HS_678_PolyA_skin  12499974               1760764                 33086694
# HS_694_PolyA_skin  15426597               1565050                 14193649
# HS_696_PolyA_skin  15875036               1643786                 16147952
# HS_698_PolyA_skin  15395967               1628249                 18775695
# HS_701_PolyA_skin  13876479               1678639                 21414830
# HS_702_PolyA_skin  13724937               1534623                 13591961
# HS_703_PolyA_skin  12254633               1416480                 15310973
#
# Stat               Unassigned_NoFeatures  Unassigned_Unmapped
# Sample
# HS_299_PolyA_skin                2406968                20866
# HS_644_PolyA_skin                1604140                13842
# HS_672_PolyA_skin                3053270                23927
# HS_678_PolyA_skin                3287873                13661
# HS_694_PolyA_skin                2687367                25302
# HS_696_PolyA_skin                3208565                27591
# HS_698_PolyA_skin                3004960                23343
# HS_701_PolyA_skin                3002180                23691
# HS_702_PolyA_skin                3347940                24893
# HS_703_PolyA_skin                2629599                20859

# %%
merged = pd.concat([pbmc_u, skin_u])

merged["sample_name"] = list(pd.Series(merged.index).apply(lambda x: x[:6]))
merged["GlobinClear"] = merged.index.str.endswith("pbmc")

# %%
merged["Total Alignments"] = merged["Assigned"] + merged["Unassigned_Ambiguity"] + merged["Unassigned_MultiMapping"] + merged["Unassigned_NoFeatures"] + merged["Unassigned_Unmapped"]

# %%
cols = ["Assigned","Unassigned_Ambiguity","Unassigned_MultiMapping","Unassigned_NoFeatures","Unassigned_Unmapped"]

for i in cols:
    merged[f"pct_{i}"] = merged[i]/merged["Total Alignments"]

# %%
cols = ["Unassigned_Ambiguity","Unassigned_MultiMapping","Unassigned_NoFeatures","Unassigned_Unmapped"]

for i in cols:
    merged[f"pct_{i}|Unassigned"] = merged[i]/(merged["Total Alignments"] - merged["Assigned"])

# %%
merged
# Out:
# Stat               Assigned  Unassigned_Ambiguity  Unassigned_MultiMapping  \
# Sample
# HS_299_pbmc        16661582               1466281                  1836890
# HS_644_pbmc        16620978               1433214                  2014020
# HS_672_pbmc        16220056               1604941                  1934489
# HS_678_pbmc        18253299               1964843                  2517403
# HS_694_pbmc        16850168               1564730                  1965102
# HS_696_pbmc        19716396               1628623                  2079723
# HS_698_pbmc        18007289               1470999                  1842819
# HS_701_pbmc        17368869               1586192                  2082506
# HS_702_pbmc        16141721               1385850                  1825262
# HS_703_pbmc        15811086               1377229                  1745300
# HS_299_PolyA_skin  14255241               1740751                 19068863
# HS_644_PolyA_skin  13612285               1662317                 24148741
# HS_672_PolyA_skin  14857851               1937898                 22922755
# HS_678_PolyA_skin  12499974               1760764                 33086694
# HS_694_PolyA_skin  15426597               1565050                 14193649
# HS_696_PolyA_skin  15875036               1643786                 16147952
# HS_698_PolyA_skin  15395967               1628249                 18775695
# HS_701_PolyA_skin  13876479               1678639                 21414830
# HS_702_PolyA_skin  13724937               1534623                 13591961
# HS_703_PolyA_skin  12254633               1416480                 15310973
#
# Stat               Unassigned_NoFeatures  Unassigned_Unmapped sample_name  \
# Sample
# HS_299_pbmc                      2046089                19516      HS_299
# HS_644_pbmc                      1937332                22735      HS_644
# HS_672_pbmc                      2020916                20494      HS_672
# HS_678_pbmc                      1617750                21843      HS_678
# HS_694_pbmc                      1803261                21825      HS_694
# HS_696_pbmc                      2767055                23201      HS_696
# HS_698_pbmc                      3527364                18372      HS_698
# HS_701_pbmc                      3182905                29270      HS_701
# HS_702_pbmc                      2601927                22085      HS_702
# HS_703_pbmc                      2477362                23095      HS_703
# HS_299_PolyA_skin                2406968                20866      HS_299
# HS_644_PolyA_skin                1604140                13842      HS_644
# HS_672_PolyA_skin                3053270                23927      HS_672
# HS_678_PolyA_skin                3287873                13661      HS_678
# HS_694_PolyA_skin                2687367                25302      HS_694
# HS_696_PolyA_skin                3208565                27591      HS_696
# HS_698_PolyA_skin                3004960                23343      HS_698
# HS_701_PolyA_skin                3002180                23691      HS_701
# HS_702_PolyA_skin                3347940                24893      HS_702
# HS_703_PolyA_skin                2629599                20859      HS_703
#
# Stat               GlobinClear  Total Alignments  pct_Assigned  \
# Sample
# HS_299_pbmc               True          22030358      0.756301
# HS_644_pbmc               True          22028279      0.754529
# HS_672_pbmc               True          21800896      0.744009
# HS_678_pbmc               True          24375138      0.748849
# HS_694_pbmc               True          22205086      0.758843
# HS_696_pbmc               True          26214998      0.752104
# HS_698_pbmc               True          24866843      0.724149
# HS_701_pbmc               True          24249742      0.716250
# HS_702_pbmc               True          21976845      0.734488
# HS_703_pbmc               True          21434072      0.737661
# HS_299_PolyA_skin        False          37492689      0.380214
# HS_644_PolyA_skin        False          41041325      0.331673
# HS_672_PolyA_skin        False          42795701      0.347181
# HS_678_PolyA_skin        False          50648966      0.246796
# HS_694_PolyA_skin        False          33897965      0.455089
# HS_696_PolyA_skin        False          36902930      0.430184
# HS_698_PolyA_skin        False          38828214      0.396515
# HS_701_PolyA_skin        False          39995819      0.346948
# HS_702_PolyA_skin        False          32224354      0.425918
# HS_703_PolyA_skin        False          31632544      0.387406
#
# Stat               pct_Unassigned_Ambiguity  pct_Unassigned_MultiMapping  \
# Sample
# HS_299_pbmc                        0.066557                     0.083380
# HS_644_pbmc                        0.065062                     0.091429
# HS_672_pbmc                        0.073618                     0.088734
# HS_678_pbmc                        0.080608                     0.103277
# HS_694_pbmc                        0.070467                     0.088498
# HS_696_pbmc                        0.062126                     0.079333
# HS_698_pbmc                        0.059155                     0.074107
# HS_701_pbmc                        0.065411                     0.085877
# HS_702_pbmc                        0.063060                     0.083054
# HS_703_pbmc                        0.064254                     0.081426
# HS_299_PolyA_skin                  0.046429                     0.508602
# HS_644_PolyA_skin                  0.040503                     0.588401
# HS_672_PolyA_skin                  0.045283                     0.535632
# HS_678_PolyA_skin                  0.034764                     0.653255
# HS_694_PolyA_skin                  0.046169                     0.418717
# HS_696_PolyA_skin                  0.044544                     0.437579
# HS_698_PolyA_skin                  0.041935                     0.483558
# HS_701_PolyA_skin                  0.041970                     0.535427
# HS_702_PolyA_skin                  0.047623                     0.421792
# HS_703_PolyA_skin                  0.044779                     0.484026
#
# Stat               pct_Unassigned_NoFeatures  pct_Unassigned_Unmapped  \
# Sample
# HS_299_pbmc                         0.092876                 0.000886
# HS_644_pbmc                         0.087947                 0.001032
# HS_672_pbmc                         0.092699                 0.000940
# HS_678_pbmc                         0.066369                 0.000896
# HS_694_pbmc                         0.081209                 0.000983
# HS_696_pbmc                         0.105552                 0.000885
# HS_698_pbmc                         0.141850                 0.000739
# HS_701_pbmc                         0.131255                 0.001207
# HS_702_pbmc                         0.118394                 0.001005
# HS_703_pbmc                         0.115581                 0.001077
# HS_299_PolyA_skin                   0.064198                 0.000557
# HS_644_PolyA_skin                   0.039086                 0.000337
# HS_672_PolyA_skin                   0.071345                 0.000559
# HS_678_PolyA_skin                   0.064915                 0.000270
# HS_694_PolyA_skin                   0.079278                 0.000746
# HS_696_PolyA_skin                   0.086946                 0.000748
# HS_698_PolyA_skin                   0.077391                 0.000601
# HS_701_PolyA_skin                   0.075062                 0.000592
# HS_702_PolyA_skin                   0.103895                 0.000772
# HS_703_PolyA_skin                   0.083130                 0.000659
#
# Stat               pct_Unassigned_Ambiguity|Unassigned  \
# Sample
# HS_299_pbmc                                   0.273113
# HS_644_pbmc                                   0.265052
# HS_672_pbmc                                   0.287581
# HS_678_pbmc                                   0.320956
# HS_694_pbmc                                   0.292204
# HS_696_pbmc                                   0.250611
# HS_698_pbmc                                   0.214445
# HS_701_pbmc                                   0.230522
# HS_702_pbmc                                   0.237501
# HS_703_pbmc                                   0.244928
# HS_299_PolyA_skin                             0.074911
# HS_644_PolyA_skin                             0.060604
# HS_672_PolyA_skin                             0.069365
# HS_678_PolyA_skin                             0.046155
# HS_694_PolyA_skin                             0.084728
# HS_696_PolyA_skin                             0.078172
# HS_698_PolyA_skin                             0.069488
# HS_701_PolyA_skin                             0.064268
# HS_702_PolyA_skin                             0.082955
# HS_703_PolyA_skin                             0.073098
#
# Stat               pct_Unassigned_MultiMapping|Unassigned  \
# Sample
# HS_299_pbmc                                      0.342143
# HS_644_pbmc                                      0.372463
# HS_672_pbmc                                      0.346630
# HS_678_pbmc                                      0.411217
# HS_694_pbmc                                      0.366971
# HS_696_pbmc                                      0.320026
# HS_698_pbmc                                      0.268650
# HS_701_pbmc                                      0.302651
# HS_702_pbmc                                      0.312806
# HS_703_pbmc                                      0.310387
# HS_299_PolyA_skin                                0.820609
# HS_644_PolyA_skin                                0.880408
# HS_672_PolyA_skin                                0.820491
# HS_678_PolyA_skin                                0.867302
# HS_694_PolyA_skin                                0.768414
# HS_696_PolyA_skin                                0.767930
# HS_698_PolyA_skin                                0.801276
# HS_701_PolyA_skin                                0.819884
# HS_702_PolyA_skin                                0.734724
# HS_703_PolyA_skin                                0.790125
#
# Stat               pct_Unassigned_NoFeatures|Unassigned  \
# Sample
# HS_299_pbmc                                    0.381109
# HS_644_pbmc                                    0.358281
# HS_672_pbmc                                    0.362117
# HS_678_pbmc                                    0.264259
# HS_694_pbmc                                    0.336749
# HS_696_pbmc                                    0.425792
# HS_698_pbmc                                    0.514226
# HS_701_pbmc                                    0.462573
# HS_702_pbmc                                    0.445908
# HS_703_pbmc                                    0.440578
# HS_299_PolyA_skin                              0.103581
# HS_644_PolyA_skin                              0.058483
# HS_672_PolyA_skin                              0.109288
# HS_678_PolyA_skin                              0.086185
# HS_694_PolyA_skin                              0.145488
# HS_696_PolyA_skin                              0.152586
# HS_698_PolyA_skin                              0.128240
# HS_701_PolyA_skin                              0.114941
# HS_702_PolyA_skin                              0.180975
# HS_703_PolyA_skin                              0.135701
#
# Stat               pct_Unassigned_Unmapped|Unassigned
# Sample
# HS_299_pbmc                                  0.003635
# HS_644_pbmc                                  0.004205
# HS_672_pbmc                                  0.003672
# HS_678_pbmc                                  0.003568
# HS_694_pbmc                                  0.004076
# HS_696_pbmc                                  0.003570
# HS_698_pbmc                                  0.002678
# HS_701_pbmc                                  0.004254
# HS_702_pbmc                                  0.003785
# HS_703_pbmc                                  0.004107
# HS_299_PolyA_skin                            0.000898
# HS_644_PolyA_skin                            0.000505
# HS_672_PolyA_skin                            0.000856
# HS_678_PolyA_skin                            0.000358
# HS_694_PolyA_skin                            0.001370
# HS_696_PolyA_skin                            0.001312
# HS_698_PolyA_skin                            0.000996
# HS_701_PolyA_skin                            0.000907
# HS_702_PolyA_skin                            0.001346
# HS_703_PolyA_skin                            0.001076

# %%
merged[['pct_Assigned','GlobinClear']].groupby('GlobinClear').mean()
# Out:
# Stat         pct_Assigned
# GlobinClear
# False            0.374792
# True             0.742718

# %%
merged.to_csv("poly_a_counts.csv")

# %%
merged = pd.read_csv("poly_a_counts_new.csv")

# %%
merged["pct_Uniquely_Mapped_Reads"] = merged["pct_Uniquely_Mapped_Reads"].str.rstrip('%').astype('float') / 100

# %%
merged[['pct_Uniquely_Mapped_Reads','GlobinClear']].groupby('GlobinClear').mean()
# Out:
#              pct_Uniquely_Mapped_Reads
# GlobinClear
# False                          0.71435
# True                           0.96584

# %%
from matplotlib.ticker import PercentFormatter
val = "pct_Uniquely_Mapped_Reads"
title = "STAR Percent Uniquely Mapped Reads"

fig, ax = plt.subplots(figsize=(5, 5), dpi=300)  # Set the figure size here

# Create the boxplot
sns.boxplot(x='GlobinClear', y=val, data=merged, ax=ax, color = "white", linecolor = "black", showfliers=False)
sns.stripplot(x='GlobinClear', y=val, data=merged, ax=ax, hue='sample_name', legend = False)

# Perform t-test (or any other test) between the two groups
group_A = merged[merged['GlobinClear']][val]
group_B = merged[~merged['GlobinClear']][val]
t_stat, p_val = ttest_ind(group_A, group_B)

# Set the title for the entire figure, not as an attribute of fig
ax.yaxis.set_major_formatter(PercentFormatter(1, decimals = 2))
ax.set_title(f'{title}\np = {p_val:.2e}')
plt.tight_layout()
fig.savefig("uniquely_mapped_reads.png")
#fig.savefig("prior_" + val.split('|')[0] + '.png')
